# %%
import pandas as pd

df = pd.read_csv("data/iphony.csv")
df['cena']
# Out:
# 0      1929.0
# 1      1250.0
# 2      2199.0
# 3       550.0
# 4       750.0
#         ...
# 223    1400.0
# 224    4899.0
# 225    1100.0
# 226     150.0
# 227    2000.0
# Name: cena, Length: 228, dtype: float64
